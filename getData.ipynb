# %%
import datetime as dt
import pandas as pd
import pandas_datareader as pdr
import yfinance as yf
import bs4
import pickle
import requests
import os

# %%
startyear = 2000
startmonth = 1
startday = 1
start = dt.datetime(startyear, startmonth, startday)

# endyear = 2020
# endmonth = 2
# endday = 1
# end = dt.datetime(endyear, endmonth, endday)

end = dt.datetime.now()

# %% [markdown]
# <h3>Get Data for S&P 500 Stocks</h3>

# %%
def save_sp500_tickers():

    resp = requests.get('http://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
    soup = bs4.BeautifulSoup(resp.text, 'lxml')
    table = soup.find('table', {'class': 'wikitable sortable'})

    tickers = []
    for row in table.find_all('tr')[1:]:
        ticker = row.find_all('td')[0].text
        if '.' in ticker:
            ticker = ticker.replace('.','-')
        ticker = ticker[:-1]
        tickers.append(ticker)

    with open('Data/tickers/sp500tickers.pickle', 'wb') as f:
        pickle.dump(tickers, f)

    # return tickers

save_sp500_tickers()

# %%
def get_sp500data_from_yahoo(reload_sp500=False):
    if reload_sp500:
        tickers = save_sp500_tickers()
    else:
        with open('Data/tickers/sp500tickers.pickle', 'rb') as f:
            tickers = pickle.load(f)

    if not os.path.exists('Data/HistoricalData'):
        os.makedirs('Data/HistoricalData')

    for ticker in tickers:
        if not os.path.exists(f'Data/HistoricalData/{ticker}.csv'):
            df = pdr.get_data_yahoo(ticker, start, end)
            df.reset_index(inplace=True)
            df.set_index('Date', inplace=True)
            df.to_csv(f'Data/HistoricalData/{ticker}.csv')
        else:
            print(f'Already have {ticker}')

get_sp500data_from_yahoo()
# Out:
# Already have MMM
# Already have ABT
# Already have ABBV
# Already have ABMD
# Already have ACN
# Already have ATVI
# Already have ADBE
# Already have AMD
# Already have AAP
# Already have AES
# Already have AFL
# Already have A
# Already have APD
# Already have AKAM
# Already have ALK
# Already have ALB
# Already have ARE
# Already have ALXN
# Already have ALGN
# Already have ALLE
# Already have LNT
# Already have ALL
# Already have GOOGL
# Already have GOOG
# Already have MO
# Already have AMZN
# Already have AMCR
# Already have AEE
# Already have AAL
# Already have AEP
# Already have AXP
# Already have AIG
# Already have AMT
# Already have AWK
# Already have AMP
# Already have ABC
# Already have AME
# Already have AMGN
# Already have APH
# Already have ADI
# Already have ANSS
# Already have ANTM
# Already have AON
# Already have AOS
# Already have APA
# Already have AAPL
# Already have AMAT
# Already have APTV
# Already have ADM
# Already have ANET
# Already have AJG
# ...

# %% [markdown]
# <h3>Get Data for Dax stocks</h3>

# %%
def save_Dax_Tickers():

    response = requests.get('https://de.wikipedia.org/wiki/DAX')
    soup = bs4.BeautifulSoup(response.text, 'lxml')
    table = soup.find('table', {'class': 'wikitable sortable'})

    tickers = []
    for row in table.find_all('tr')[1:]:
        ticker = row.find_all('td')[1].text
        if '.' in ticker:
            ticker = ticker.replace('.','-')
        tickers.append(ticker + '.DE')

    with open('Data/tickers/DAX_tickers.pickle', 'wb') as f:
        pickle.dump(tickers, f)

    # return tickers

save_Dax_Tickers()

# %%
def get_daxdata_from_yahoo(reload_dax=False):
    if reload_dax:
        tickers = save_Dax_Tickers()
    else:
        with open('Data/tickers/Dax_tickers.pickle', 'rb') as f:
            tickers = pickle.load(f)

    if not os.path.exists('Data/HistoricalData'):
        os.makedirs('Data/HistoricalData')

    for ticker in tickers:
        if not os.path.exists(f'Data/HistoricalData/{ticker}.csv'):
            df = pdr.get_data_yahoo(ticker, start, end)
            df.reset_index(inplace=True)
            df.set_index('Date', inplace=True)
            df.to_csv(f'Data/HistoricalData/{ticker}.csv')
        else:
            print(f'Already have {ticker}')

get_daxdata_from_yahoo()
# Out:
# Already have ADS.DE
# Already have ALV.DE
# Already have BAS.DE
# Already have BAYN.DE
# Already have BEI.DE
# Already have BMW.DE
# Already have CON.DE
# Already have 1COV.DE
# Already have DAI.DE
# Already have DHER.DE
# Already have DBK.DE
# Already have DB1.DE
# Already have DPW.DE
# Already have DTE.DE
# Already have DWNI.DE
# Already have EOAN.DE
# Already have FRE.DE
# Already have FME.DE
# Already have HEI.DE
# Already have HEN3.DE
# Already have IFX.DE
# Already have LIN.DE
# Already have MRK.DE
# Already have MTX.DE
# Already have MUV2.DE
# Already have RWE.DE
# Already have SAP.DE
# Already have SIE.DE
# Already have VOW3.DE
# Already have VNA.DE

# %% [markdown]
# <h3>Get data for TecDax stocks</h3>

# %%
def save_TecDax_Tickers():

    response = requests.get('https://de.wikipedia.org/wiki/TecDAX')
    soup = bs4.BeautifulSoup(response.text, 'lxml')
    table = soup.find('table', {'class': 'wikitable sortable zebra'})

    tickers = []
    for row in table.find_all('tr')[1:]:
        ticker = row.find_all('td')[2].text
        if '.' in ticker:
            ticker = ticker.replace('.','-')
        elif '\n' in ticker:
            ticker = ticker.replace('\n','')
        tickers.append(ticker + '.DE')

    with open('Data/tickers/TecDAX_tickers.pickle', 'wb') as f:
        pickle.dump(tickers, f)

    # return tickers

save_TecDax_Tickers()

# %%
def get_tecdaxdata_from_yahoo(reload_tecdax=False):
    if reload_tecdax:
        tickers = save_TecDax_Tickers()
    else:
        with open('Data/tickers/TecDax_tickers.pickle', 'rb') as f:
            tickers = pickle.load(f)

    if not os.path.exists('Data/HistoricalData'):
        os.makedirs('Data/HistoricalData')

    for ticker in tickers:
        if not os.path.exists(f'Data/HistoricalData/{ticker}.csv'):
            df = pdr.get_data_yahoo(ticker, start, end)
            df.reset_index(inplace=True)
            df.set_index('Date', inplace=True)
            df.to_csv(f'Data/HistoricalData/{ticker}.csv')
        else:
            print(f'Already have {ticker}')

get_tecdaxdata_from_yahoo()
# Out:
# Already have DRI.DE
# Already have AIXA.DE
# Already have BC8.DE
# Already have COK.DE
# Already have AFX.DE
# Already have COP.DE
# Already have DTE.DE
# Already have DRW3.DE
# Already have EUZ.DE
# Already have EVT.DE
# Already have FNTN.DE
# Already have IFX.DE
# Already have JEN.DE
# Already have LPK.DE
# Already have MOR.DE
# Already have NEM.DE
# Already have NWO.DE
# Already have NDX1.DE
# Already have PFV.DE
# Already have QIA.DE
# Already have SANT.DE
# Already have SAP.DE
# Already have SRT3.DE
# Already have SHL.DE
# Already have WAF.DE
# Already have SOW.DE
# Already have TMV.DE
# Already have O2D.DE
# Already have UTDI.DE
# Already have VAR1.DE

# %% [markdown]
# <h3>Get Data for Ark-Invest-Fonds stocks</h3>

# %%
df_ARKQ = pd.read_csv('Data/Ark_Invest/ARK_AUTONOMOUS_TECHNOLOGY_&_ROBOTICS_ETF_ARKQ/22_02_2021.csv')
# print('df_ARKQ\n')
# print(df_ARKQ.head())

df_ARKF = pd.read_csv('Data/Ark_Invest/ARK_FINTECH_INNOVATION_ETF_ARKF/22_02_2021.csv')
# print('\ndf_ARKF\n')
# print(df_ARKF.head())

df_ARKG = pd.read_csv('Data/Ark_Invest/ARK_GENOMIC_REVOLUTION_MULTISECTOR_ETF_ARKG/22_02_2021.csv')
# print('\ndf_ARKG\n')
# print(df_ARKG.head())

df_ARKK = pd.read_csv('Data/Ark_Invest/ARK_INNOVATION_ETF_ARKK/22_02_2021.csv')
# print('\ndf_ARKK\n')
# print(df_ARKK.head())

df_ARKW = pd.read_csv('Data/Ark_Invest/ARK_NEXT_GENERATION_INTERNET_ETF_ARKW/22_02_2021.csv')
# print('\ndf_ARKW\n')
# print(df_ARKW.head())

# %%
df_ArkTotal = pd.concat([df_ARKQ, df_ARKF, df_ARKG, df_ARKK, df_ARKW], ignore_index=True)
# print(df_ArkTotal)
print(len(df_ArkTotal))
# Out:
# 281

# %%
df_ArkTotalCleared = df_ArkTotal.dropna()
# print(df_ArkTotal)
print(len(df_ArkTotalCleared))
# Out:
# 261

# %%
df_ArkTotalCleared = df_ArkTotalCleared[~df_ArkTotalCleared.ticker.str.contains('ONVO')]
df_ArkTotalCleared = df_ArkTotalCleared[~df_ArkTotalCleared.ticker.str.contains('ADYEN')]
df_ArkTotalCleared = df_ArkTotalCleared[~df_ArkTotalCleared.ticker.str.contains('9923')]
df_ArkTotalCleared = df_ArkTotalCleared[~df_ArkTotalCleared.ticker.str.contains('6060')]
df_ArkTotalCleared = df_ArkTotalCleared[~df_ArkTotalCleared.ticker.str.contains('3690')]
df_ArkTotalCleared = df_ArkTotalCleared[~df_ArkTotalCleared.ticker.str.contains('4689')]
df_ArkTotalCleared = df_ArkTotalCleared[~df_ArkTotalCleared.ticker.str.contains('TCS LI')]
df_ArkTotalCleared = df_ArkTotalCleared[~df_ArkTotalCleared.ticker.str.contains('4477')]
df_ArkTotalCleared = df_ArkTotalCleared[~df_ArkTotalCleared.ticker.str.contains('TREE UW')]
df_ArkTotalCleared = df_ArkTotalCleared[~df_ArkTotalCleared.ticker.str.contains('1833')]
df_ArkTotalCleared = df_ArkTotalCleared[~df_ArkTotalCleared.ticker.str.contains('KSPI')]
df_ArkTotalCleared = df_ArkTotalCleared[~df_ArkTotalCleared.ticker.str.contains('TAK UN')]
df_ArkTotalCleared = df_ArkTotalCleared[~df_ArkTotalCleared.ticker.str.contains('ARCT UQ')]

print(len(df_ArkTotalCleared))
# Out:
# 244

# %%
df_ArkTotalCleared.to_csv('ArkTotal.csv')

# %%
def get_ArkInvestData_from_yahoo():
    
    tickers = df_ArkTotalCleared['ticker']
    
    if not os.path.exists('Data/HistoricalData'):
        os.makedirs('Data/HistoricalData')

    for ticker in tickers:
        if not os.path.exists(f'Data/HistoricalData/{ticker}.csv'):
            df = pdr.get_data_yahoo(ticker, start, end)
            df.reset_index(inplace=True)
            df.set_index('Date', inplace=True)
            df.to_csv(f'Data/HistoricalData/{ticker}.csv')
        else:
            print(f'Already have {ticker}')

get_ArkInvestData_from_yahoo()
# Out:
# Already have TSLA
# Already have BIDU
# Already have JD
# Already have DE
# Already have TRMB
# Already have TER
# Already have KTOS
# Already have GOOG
# Already have MTLS
# Already have NXPI
# Already have KMTUY
# Already have CAT
# Already have TSM
# Already have NNDM
# Already have NVDA
# Already have IRDM
# Already have LMT
# Already have TDY
# Already have BYDDY
# Already have WKHS
# Already have SNPS
# Already have SPCE
# Already have AVAV
# Already have NIU
# Already have ISRG
# Already have SSYS
# Already have MGA
# Already have TWOU
# Already have TCEHY
# Already have ANSS
# Already have RAVN
# Already have AMZN
# Already have PRLB
# Already have FLIR
# Already have XLNX
# Already have XONE
# Already have ROK
# Already have BABA
# Already have PCAR
# Already have ESLT
# Already have AAPL
# Already have ADSK
# Already have EXPC
# Already have ACIC
# Already have VUZI
# Already have HON
# Already have SPLK
# Already have SQ
# Already have PYPL
# Already have Z
# ...
